# %%
# !git clone https://github.com/shreya172004/SMART-WARDROBE.git
# Out:
# Cloning into 'SMART-WARDROBE'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 73 (delta 43), reused 34 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 1.07 MiB | 45.62 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_12360/815680317.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive',force_remount=True)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
# %cd SMART-WARDROBE
# Out:
# /content/SMART-WARDROBE

# %%
import sys
sys.path.append("/content/SMART-WARDROBE/src")

# %%
import sys
sys.path.append("/content/SMART-WARDROBE/src")

from model import ViBEModel
print("Model import successful")
# Out:
# Model import successful

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.04 KiB | 1.04 MiB/s, done.
# From https://github.com/shreya172004/SMART-WARDROBE
#    bedcbe7..8db8924  main       -> origin/main
# Updating bedcbe7..8db8924
# Fast-forward
#  src/train.py | 107 ++++++++++++++++++++++++++++++++++++++---------------------
#  1 file changed, 69 insertions(+), 38 deletions(-)

# %%
# !python src/train.py
# Out:
# Using device: cuda
# Training samples: 9901
# Validation samples: 2123
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 170MB/s]
# 100% 619/619 [1:40:42<00:00,  9.76s/it]
#
# Epoch [1/10]
# Train Loss: 0.5267 | Train Acc: 0.8492
# ...

# %%
torch.save(model.state_dict(), "epoch1_model.pth")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8308/3534078163.py in <cell line: 0>()
# ----> 1 torch.save(model.state_dict(), "epoch1_model.pth")
#
# NameError: name 'torch' is not defined

# %%
# !python src/train.py
# Out:
# Using device: cuda
# Training samples: 9901
# Validation samples: 2123
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 245MB/s]
# 100% 619/619 [1:39:59<00:00,  9.69s/it]
#
# Epoch [1/2]
# Train Loss: 0.5306 | Train Acc: 0.8477
# ...

# %%
# !ls /content
# Out:
# sample_data

# %%
import matplotlib.pyplot as plt

train_losses = [0.5306, 0.3327]
val_losses   = [0.3862, 0.2947]

epochs = [1, 2]

plt.figure(figsize=(8,5))
plt.plot(epochs, train_losses, marker='o', label="Train Loss")
plt.plot(epochs, val_losses, marker='o', label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()
